# %%
# For UCSD Guardian
# Link to Data: 
# Author: Halle Davis
# Date: 11/22

# %%
import openpyxl
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
plotly.tools.set_credentials_file(username='halle.davis', api_key='uolxs6kfav')
from collections import OrderedDict
import pandas as pd
import numpy as np
import bokeh
from bokeh.charts import Donut, output_file, show

# %%
df = pd.read_csv('1314.csv')
df
# Out:
#              Student Characteristics       N       % GPA Mean % GPA > 3.0  \
# 0                             Gender     NaN     NaN      NaN         NaN
# 1                             Female  3123.0   52.0%     3.20       40.2%
# 2                               Male  2878.0   48.0%     3.12       39.2%
# 3                          Ethnicity     NaN     NaN      NaN         NaN
# 4                        African Am.   108.0    1.8%     3.09       41.7%
# 5                              Asian  2488.0   41.5%     3.10       41.2%
# 6                        Mexican Am.   573.0    9.5%     3.03       36.8%
# 7                           Filipino   235.0    3.9%     3.03       35.3%
# 8                             Latino   199.0    3.3%     3.08       35.7%
# 9                         Native Am.    25.0    0.4%     3.25       56.0%
# 10                         Caucasian  1296.0   21.6%     3.24       40.4%
# 11                             Other  1077.0   17.9%     3.34       37.9%
# 12                 Disciplinary Area     NaN     NaN      NaN         NaN
# 13                              Arts   206.0    3.4%     3.42       39.8%
# 14                        Humanities   170.0    2.8%     3.30       37.6%
# 15                       Engineering  1063.0   17.7%     3.16       43.1%
# 16                      Science/Math   626.0   10.4%     3.12       36.3%
# 17                           Biology  1060.0   17.7%     3.22       39.4%
# 18                    Social Science  2873.0   47.9%     3.13       39.4%
# 19                       Dbl/Special     3.0    0.0%     3.50       66.7%
# 20                           College     NaN     NaN      NaN         NaN
# 21                           Revelle   919.0   15.3%     3.12       35.6%
# 22                              Muir  1011.0   16.8%     3.20       39.9%
# 23                          Marshall  1118.0   18.6%     3.15       38.7%
# 24                            Warren  1032.0   17.2%     3.16       39.2%
# 25                         Roosevelt   975.0   16.2%     3.17       42.2%
# 26                             Sixth   946.0   15.8%     3.18       42.6%
# 27                       School Type     NaN     NaN      NaN         NaN
# 28                       High School  3623.0   60.4%     3.20       41.2%
# 29                       2yr College  2262.0   37.7%     3.10       37.0%
# ..                               ...     ...     ...      ...         ...
# 222                      African Am.    55.0    1.9%     3.15       43.6%
# 223                            Asian  1310.0   45.6%     3.07       38.7%
# 224                      Mexican Am.   333.0   11.6%     3.06       40.5%
# 225                         Filipino   104.0    3.6%     3.05       31.7%
# 226                           Latino   119.0    4.1%     3.04       37.0%
# 227                       Native Am.    15.0    0.5%     3.22       66.7%
# 228                        Caucasian   634.0   22.1%     3.27       41.2%
# 229                            Other   303.0   10.5%     3.23       38.6%
# 230                          College     NaN     NaN      NaN         NaN
# 231                          Revelle   325.0   11.3%     3.03       34.2%
# 232                             Muir   522.0   18.2%     3.16       38.9%
# 233                         Marshall   624.0   21.7%     3.13       39.4%
# 234                           Warren   370.0   12.9%     3.09       37.3%
# 235                        Roosevelt   580.0   20.2%     3.16       41.6%
# 236                            Sixth   452.0   15.7%     3.15       42.5%
# 237                      School Type     NaN     NaN      NaN         NaN
# 238                      High School  1568.0   54.6%     3.17       41.2%
# 239                      2yr College  1239.0   43.1%     3.08       36.5%
# 240                4yr College/Univ.    62.0    2.2%     3.26       53.2%
# 241                          Unknown     4.0    0.1%     2.90        0.0%
# 242  First Generation College Status     NaN     NaN      NaN         NaN
# 243                 First Generation  1056.0   36.8%     3.06       37.9%
# 244             Not First Generation  1817.0   63.2%     3.17       40.2%
# 245                           Income     NaN     NaN      NaN         NaN
# 246                   High: > $98401   700.0   24.4%     3.19       42.6%
# 247     Medium High: $65601 - $98400   285.0    9.9%     3.16       39.3%
# 248      Medium Low: $32801 - $65600   537.0   18.7%     3.13       39.7%
# 249                    Low: < $32800   706.0   24.6%     3.05       38.1%
# 250               Missing/Undeclared   645.0   22.5%     3.13       37.1%
# 251            Total Social Sciences  2873.0  100.0%     3.13       39.4%
#
#     % GPA > 3.5 Units Mean Freshman Mean Transfer Mean
# 0           NaN        NaN           NaN           NaN
# 1         28.0%        214          12.9           7.7
# 2         22.9%        218          13.4           8.5
# 3           NaN        NaN           NaN           NaN
# 4         17.6%        216          13.5           8.7
# 5         19.8%        215          13.2           7.6
# 6         14.3%        212          13.7           8.5
# 7         14.5%        215          13.4           8.3
# 8         22.6%        214          13.6           8.7
# 9         20.0%        210          11.6           8.5
# 10        31.2%        213          12.9           8.4
# 11        42.0%        224          12.6           8.5
# 12          NaN        NaN           NaN           NaN
# 13        46.6%        213          13.7           7.8
# 14        37.6%        211          13.3           8.5
# 15        23.3%        237          13.5           9.8
# 16        24.1%        223          13.1           8.4
# 17        30.0%        221          13.0           8.8
# 18        22.8%        205          12.9           7.5
# 19        33.3%        202          12.0           8.0
# 20          NaN        NaN           NaN           NaN
# 21        23.6%        224          13.3           8.8
# 22        28.5%        214          12.9           8.0
# 23        25.8%        209          13.1           7.7
# 24        25.5%        219          13.0           8.6
# 25        24.5%        214          13.3           8.0
# 26        25.3%        215          13.0           8.1
# 27          NaN        NaN           NaN           NaN
# 28        27.8%        220          13.1            --
# 29        21.9%        208            --           8.1
# ..          ...        ...           ...           ...
# 222       18.2%        209          13.4           7.9
# 223       18.4%        204          13.0           7.1
# 224       15.6%        204          13.3           7.8
# 225       15.4%        207          12.9           7.7
# 226       19.3%        203          13.2           7.6
# 227       13.3%        207          11.1           8.0
# 228       33.3%        203          12.6           7.6
# 229       33.3%        210          12.7           8.1
# 230         NaN        NaN           NaN           NaN
# 231       16.9%        214          13.4           7.8
# 232       26.1%        204          12.7           7.6
# 233       23.9%        199          12.8           7.2
# 234       19.7%        205          12.9           7.5
# 235       24.1%        205          13.1           7.6
# 236       22.8%        205          12.8           7.5
# 237         NaN        NaN           NaN           NaN
# 238       24.7%        210          12.9            --
# 239       20.3%        198            --           7.5
# 240       29.0%        205            --            --
# 241        0.0%        204            --            --
# 242         NaN        NaN           NaN           NaN
# 243       17.2%        203          13.3           7.3
# 244       26.1%        205          12.7           7.6
# 245         NaN        NaN           NaN           NaN
# 246       26.0%        202          12.5           6.9
# 247       25.3%        204          12.6           7.2
# 248       22.7%        207          13.0           7.4
# 249       17.1%        206          13.3           7.7
# 250       24.7%        204          12.9           7.9
# 251       22.8%        205          12.9           7.5
#
# [252 rows x 9 columns]

# %%
#Overall GPA Props by Income

x = ['Low', 'Medium Low', 'Medium High', 'High', 'N/A']

#% GPA  3.0-3.5
trace1 = {
        'x': x,
        'y': [39.20, 39, 40.2, 41.4, 38.6],
        'name': 'GPA 3.0-3.5',
        'type': 'bar'
};
#% GPA > 3.5
trace2 = {
        'x': x,
        'y': [17.6, 24.4, 25.4, 30.8, 28.6],
        'name': 'GPA > 3.5',
        'type': 'bar'
}

data = [trace1, trace2];
layout = {
        'xaxis': {'title': 'Income Level'},
        'yaxis': {'title': 'GPA'},
        'barmode': 'relative',
        'title': 'Income GPA'
};
py.iplot({'data': data, 'layout': layout}, filename='bar1')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~halle.davis/182.embed" height="525px" width="100%"></iframe>

# %%
#Overall GPA Mean by Income
data = [go.Bar(
            x=['Low', 'Medium Low', 'Medium High', 'High'],
            y=[3.06, 3.15, 3.17, 3.24]
    )]
py.iplot(data, filename='bar2')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~halle.davis/184.embed" height="525px" width="100%"></iframe>
